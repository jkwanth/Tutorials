# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

N=4
theta = np.linspace(0, 2*np.pi, N, endpoint=False)
radii = 9 * np.random.rand(N) + 1
width = np.pi / 4 * (np.random.rand(N) + 1)

ax = plt.subplot(111,polar=True)
bars = ax.bar(theta, radii, width=width,bottom=0)

for r, bar in zip(radii,bars):
    bar.set_facecolor(plt.cm.jet(r/10))
    bar.set_alpha(0.5)

# %%
pwd
# Out:
# u'/Users/jkwan/Dropbox/Sync/Notes/NB/Tutorials/Python'

# %%
ls
# Out:
# Installation.ipynb  Untitled.ipynb      load.py

# %%
cd ..
# Out:
# /Users/jkwan/Dropbox/Sync/Notes/NB/Tutorials

# %%
cd python
# Out:
# /Users/jkwan/Dropbox/Sync/Notes/NB/Tutorials/Python

# %%
cat load.py
# Out:
# for i in range(5):
# 	print ('foobar')

# %%
run load.py
# Out:
# foobar
# foobar
# foobar
# foobar
# foobar

# %%
# %load load.py
for i in range(5):
	print ('foobar')
# Out:
# foobar
# foobar
# foobar
# foobar
# foobar

# %%
# %%file saved.py
print('this file is saved using ipython magic')
# Out:
# Writing saved.py

# %%
cat saved.py
# Out:
# print('this file is saved using ipython magic')

# %%
from pylab import plot, show, legend
from random import normalvariate

x = [normalvariate(0,1) for i in range(80)]
plot(x, 'b-', label="white noise")
legend()
show()
